# %% [markdown]
# # Regressão Linear Múltipla

# %% [markdown]
# # Base de preços das casas

# %%
# Importações para o projeto

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
base_casas = pd.read_csv('/content/drive/MyDrive/datasets/house_prices.csv')
base_casas
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
base_casas.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Separando previsores e classe

x_casas = base_casas.iloc[:, 3:19]  # pegando da coluna 3 até a coluna 18
y_casas = base_casas['price'] # Pegando somente a coluna alvo que é 'price'

# %%
x_casas.shape, y_casas.shape
# Out:
# ((21613, 16), (21613,))

# %%
# Dividindo entre base de treinamento e teste

x_casas_treinamento, x_casas_teste, y_casas_treinamento, y_casas_teste = train_test_split(x_casas, y_casas, test_size=0.3, random_state=0)

# %%
# Verificando o tamanho das colunas

print(x_casas_treinamento.shape, y_casas_treinamento.shape)
print(x_casas_teste.shape, y_casas_teste.shape)
# Out:
# (15129, 16) (15129,)
# (6484, 16) (6484,)

# %%
# Criando regressor múltiplo e fazendo o treinamento

regressor_multiplo_casas = LinearRegression()
regressor_multiplo_casas.fit(x_casas_treinamento, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
# b0

regressor_multiplo_casas.intercept_
# Out:
# 5736222.703399369

# %%
# b1, coeficientes

regressor_multiplo_casas.coef_
# Out:
# array([-3.08423090e+04,  3.66540816e+04,  1.12179159e+02,  8.00604120e-03,
#         9.60355724e+03,  5.85441638e+05,  5.60621840e+04,  2.54795004e+04,
#         1.01092121e+05,  6.96565321e+01,  4.25226266e+01, -2.60724691e+03,
#         1.40070753e+01, -5.53557431e+02,  6.11778251e+05, -1.95564688e+05])

# %%
# Visualizando tamanho do coeficiente

len(regressor_multiplo_casas.coef_)
# Out:
# 16

# %%
# Fazendo score com variáveis de treinamento

regressor_multiplo_casas.score(x_casas_treinamento, y_casas_treinamento)
# Out:
# 0.7029888085955005

# %%
# Fazendo score com variáveis de teste (métrica que interessa)

regressor_multiplo_casas.score(x_casas_teste, y_casas_teste)
# Out:
# 0.6885414149062701

# %%
# Fazendo previsões

previsoes_multiple = regressor_multiplo_casas.predict(x_casas_teste)

# %%
# Verificando a quantidade média de erro, podendo ser para cima ou para baixo

mean_absolute_error(y_casas_teste, previsoes_multiple)

# com a regressão linear simples tinha em média 172.000 de perda
# Out:
# 123888.44377485162
